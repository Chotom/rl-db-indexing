# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_data = pd.read_csv('history.csv')

# %%
df_data
# Out:
#       episode  step  state  action  reward  next_state           q  max_a  \
# 0           0     0      1       3   130.0           1    0.000000      1
# 1           0     1      1       1   110.0           1    0.000000      0
# 2           0     2      1       2   100.0           1    0.000000      3
# 3           0     3      1       5   120.0           1    0.000000      3
# 4           0     4      1       4   100.0           1    0.000000      5
# ...       ...   ...    ...     ...     ...         ...         ...    ...
# 1995       99    15      1       3   200.0           1  200.782038      2
# 1996       99    16      1       2   120.0           1  121.319996      3
# 1997       99    17      1       3   200.0           1  200.794972      2
# 1998       99    18      1       2   120.0           1  121.320025      3
# 1999       99    19      1       3   200.0           1  200.807519      2
#
#            max_q  total_reward  exploration_probability  random_action
# 0       0.000000         130.0             9.000000e-01           True
# 1       0.000000         240.0             9.000000e-01           True
# 2       1.300000         340.0             9.000000e-01           True
# 3       1.300000         460.0             9.000000e-01           True
# 4       2.400260         560.0             9.000000e-01           True
# ...          ...           ...                      ...            ...
# 1995  121.319996        2570.0             3.848643e-13          False
# 1996  132.147996        2690.0             3.848643e-13          False
# 1997  121.320025        2890.0             3.848643e-13          False
# 1998  132.156360        3010.0             3.848643e-13          False
# 1999  121.320056        3210.0             3.848643e-13          False
#
# [2000 rows x 12 columns]

# %%
plt.plot(df_data['exploration_probability'])

# %%
plt.plot(df_data['total_reward'])

# %%
plt.plot(df_data['max_q'])

# %%
plt.plot(df_data['q'])

# %%
plt.plot(df_data['reward'])
