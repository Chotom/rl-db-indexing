# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_data = pd.read_csv('agent_history.csv')

# %%
df_data
# Out:
#       episode  step      state  action  reward next_state           q  max_a  \
# 0           0     0  [0, 0, 0]       1   100.0  [1, 0, 0]    0.000000      0
# 1           1     0  [1, 0, 0]       3   110.0  [1, 1, 0]    0.000000      0
# 2           2     0  [1, 1, 0]       0   130.0  [0, 1, 0]    0.000000      1
# 3           3     0  [0, 1, 0]       5   200.0  [0, 1, 1]    0.000000      1
# 4           4     0  [0, 1, 1]       2   120.0  [0, 0, 1]    0.000000      3
# ...       ...   ...        ...     ...     ...        ...         ...    ...
# 3995      195    19  [1, 1, 1]       0   200.0  [0, 1, 1]  977.777778      1
# 3996      196    19  [0, 1, 1]       1   190.0  [1, 1, 1]  972.222222      0
# 3997      197    19  [1, 1, 1]       0   200.0  [0, 1, 1]  977.777778      1
# 3998      198    19  [0, 1, 1]       1   190.0  [1, 1, 1]  972.222222      0
# 3999      199    19  [1, 1, 1]       0   200.0  [0, 1, 1]  977.777778      1
#
#            max_q   td_target  td_error  total_reward  exploration_probability  \
# 0       0.000000  100.000000     100.0         100.0                 0.900000
# 1       0.000000  110.000000     110.0         210.0                 0.900000
# 2      15.000000  142.000000     142.0         340.0                 0.900000
# 3      15.000000  212.000000     212.0         540.0                 0.900000
# 4      16.500000  133.200000     133.2         660.0                 0.900000
# ...          ...         ...       ...           ...                      ...
# 3995  972.222222  977.777778       0.0       38070.0                 0.003805
# 3996  977.777778  972.222222       0.0       38260.0                 0.003805
# 3997  972.222222  977.777778       0.0       38460.0                 0.003805
# 3998  977.777778  972.222222       0.0       38650.0                 0.003805
# 3999  972.222222  977.777778       0.0       38850.0                 0.003805
#
#       random_action
# 0              True
# 1              True
# 2              True
# 3              True
# 4              True
# ...             ...
# 3995          False
# 3996          False
# 3997          False
# 3998          False
# 3999          False
#
# [4000 rows x 14 columns]

# %%
plt.plot(df_data['exploration_probability'], '.')

# %%
plt.plot(df_data['total_reward'], '.')

# %%
plt.figure(figsize=(12, 4))
plt.subplot(121)
plt.plot(df_data[df_data['random_action']==False]['max_q'], '.')
plt.plot(df_data[df_data['random_action']==True]['max_q'], '.', alpha=0.4)
plt.subplot(122)
plt.plot(df_data['td_error'], 'r.', alpha=0.3)

# %%
plt.plot(df_data['q'], '.')

# %%
plt.plot(df_data['td_target'], '.')

# %%
plt.plot(df_data['td_error'], 'o', alpha=0.1)

# %%
plt.plot(df_data['reward'], 'o', alpha=0.05)
